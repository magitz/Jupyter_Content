# %% [markdown]
# # From neuron to neural net
#
# Last time, we looked at a single neuron. We discussed the parallels between that neuron with two weights and linear regression. As we add more features (columns in our X matrix), we can add more neurons.
#
# ## Activation Functions
#
# However, as we add neurons, each neuron still mostly functions like linear regression. The next thing we can add to our neuron is an **activation function**. Activation functions adjust the output of a neuron by adding some function before the final output. Below are the "linear" activation function that we have modeled so far, plus the more common **ReLU (Rectified Linear Unit)** and **Sigmoid** activation functions.
#
# ![Diagrams of the linear, ReLU and Sigmoid activation functions](images/Activation_function_diagrams.png)
#
#
# Again, the activation function is applied to the output of a neuron and is a hyperparameter of the model. In practice, while layers may use different activation functions, the same function is applied to **all neurons** of each layer. Below is a single neuron with a couple of possible activation functions.
#
# ![Diagram of a neuron with activation function](images/Activation_function.png)
#
# ## Layers
#
# As we get multiple neurons, we need some way of coordinating their output so we can add a layer to gather the output from multiple neurons into the needed number of outputs (more on that later). However, the other thing that layers do is allow deeper networks with multiple layers, each selected for functional or empirical reasons. This is where deep learning gets its name--as networks grow to have more and more layers of neurons, we refer to them as deep networks--there is no agreed-upon cutoff here...more than three???
#
# ![A two layer neural network](images/Neural_network.png)

# %%
import pandas as pd
import numpy as np
import os
os.environ['KERAS_BACKEND'] = 'torch'
import keras
from keras import layers
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from keras.layers import Dense, Input

from sklearn.model_selection import train_test_split

# %%
from sklearn.datasets import load_digits
digits = load_digits()
digits.data.shape
# Out:
# (1797, 64)

# %%
print(digits.keys())
# Out:
# dict_keys(['data', 'target', 'frame', 'feature_names', 'target_names', 'images', 'DESCR'])

# %%
digits.data[0]
# Out:
# array([ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.,  0.,  0., 13., 15., 10.,
#        15.,  5.,  0.,  0.,  3., 15.,  2.,  0., 11.,  8.,  0.,  0.,  4.,
#        12.,  0.,  0.,  8.,  8.,  0.,  0.,  5.,  8.,  0.,  0.,  9.,  8.,
#         0.,  0.,  4., 11.,  0.,  1., 12.,  7.,  0.,  0.,  2., 14.,  5.,
#        10., 12.,  0.,  0.,  0.,  0.,  6., 13., 10.,  0.,  0.,  0.])

# %%
digits.images[0]
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
# Get our X and y
X = digits.data / 16.0  # pixels are 0-16; scale to 0-1
y = digits.target

# %%
X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.25, random_state=42, stratify=y
)

# %%
# Data is already normalized to 0-1 above, so no additional scaling is needed.
X_train.shape, X_val.shape
# Out:
# ((1347, 64), (450, 64))

# %%
# Setup our model
# Flatten each 8x8 grayscale image and classify into 10 digit classes.
model = keras.Sequential([
    layers.Input(shape=(64,)),
    layers.Dense(10, activation="relu"),
    layers.Dense(10, activation="softmax")
])

model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_10 (Dense)                │ (None, 10)             │           650 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 10)             │           110 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 760 (2.97 KB)
#  Trainable params: 760 (2.97 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Set some model hyperparameters
from keras.optimizers import Adam

lr = 0.001  # Start with Adam default.
optimizer = Adam(learning_rate=lr)

# Use sparse categorical crossentropy for integer labels 0-9.
model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
# Now we can fit the model
# Let's also save the training history for plotting

history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=150, batch_size=10, verbose=1)
# Out:
# Epoch 1/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1347 - loss: 2.2921 - val_accuracy: 0.2867 - val_loss: 2.1005
# Epoch 2/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3578 - loss: 2.0109 - val_accuracy: 0.4778 - val_loss: 1.7052
# Epoch 3/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5515 - loss: 1.6160 - val_accuracy: 0.6689 - val_loss: 1.3525
# Epoch 4/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7157 - loss: 1.2609 - val_accuracy: 0.7467 - val_loss: 1.0640
# Epoch 5/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7736 - loss: 1.0005 - val_accuracy: 0.8044 - val_loss: 0.8652
# Epoch 6/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8094 - loss: 0.8311 - val_accuracy: 0.8356 - val_loss: 0.7247
# Epoch 7/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8511 - loss: 0.6668 - val_accuracy: 0.8578 - val_loss: 0.6307
# Epoch 8/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8588 - loss: 0.6014 - val_accuracy: 0.8756 - val_loss: 0.5551
# Epoch 9/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8800 - loss: 0.5272 - val_accuracy: 0.8800 - val_loss: 0.5013
# Epoch 10/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8809 - loss: 0.4664 - val_accuracy: 0.8911 - val_loss: 0.4576
# Epoch 11/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9127 - loss: 0.3926 - val_accuracy: 0.8933 - val_loss: 0.4205
# Epoch 12/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9053 - loss: 0.3887 - val_accuracy: 0.8911 - val_loss: 0.3946
# Epoch 13/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8991 - loss: 0.3657 - val_accuracy: 0.9000 - val_loss: 0.3640
# Epoch 14/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9213 - loss: 0.3274 - val_accuracy: 0.9044 - val_loss: 0.3449
# Epoch 15/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9250 - loss: 0.2991 - val_accuracy: 0.9067 - val_loss: 0.3241
# Epoch 16/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9363 - loss: 0.2838 - val_accuracy: 0.9178 - val_loss: 0.3060
# Epoch 17/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9311 - loss: 0.2776 - val_accuracy: 0.9222 - val_loss: 0.2872
# Epoch 18/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9340 - loss: 0.2763 - val_accuracy: 0.9222 - val_loss: 0.2731
# Epoch 19/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9486 - loss: 0.2342 - val_accuracy: 0.9244 - val_loss: 0.2598
# Epoch 20/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9536 - loss: 0.2158 - val_accuracy: 0.9267 - val_loss: 0.2473
# Epoch 21/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9490 - loss: 0.2084 - val_accuracy: 0.9356 - val_loss: 0.2339
# Epoch 22/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9516 - loss: 0.2085 - val_accuracy: 0.9311 - val_loss: 0.2284
# Epoch 23/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9541 - loss: 0.1999 - val_accuracy: 0.9333 - val_loss: 0.2178
# Epoch 24/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9598 - loss: 0.1782 - val_accuracy: 0.9378 - val_loss: 0.2105
# Epoch 25/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9535 - loss: 0.1794 - val_accuracy: 0.9356 - val_loss: 0.2024
# Epoch 26/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9681 - loss: 0.1583 - val_accuracy: 0.9444 - val_loss: 0.1964
# Epoch 27/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9695 - loss: 0.1461 - val_accuracy: 0.9444 - val_loss: 0.1860
# Epoch 28/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9651 - loss: 0.1527 - val_accuracy: 0.9467 - val_loss: 0.1797
# Epoch 29/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9670 - loss: 0.1430 - val_accuracy: 0.9467 - val_loss: 0.1741
# Epoch 30/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9717 - loss: 0.1372 - val_accuracy: 0.9533 - val_loss: 0.1714
# Epoch 31/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9643 - loss: 0.1331 - val_accuracy: 0.9511 - val_loss: 0.1639
# Epoch 32/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9728 - loss: 0.1254 - val_accuracy: 0.9467 - val_loss: 0.1635
# Epoch 33/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9754 - loss: 0.1099 - val_accuracy: 0.9511 - val_loss: 0.1629
# Epoch 34/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9633 - loss: 0.1251 - val_accuracy: 0.9600 - val_loss: 0.1564
# Epoch 35/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9842 - loss: 0.1032 - val_accuracy: 0.9578 - val_loss: 0.1503
# Epoch 36/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9683 - loss: 0.1207 - val_accuracy: 0.9533 - val_loss: 0.1501
# Epoch 37/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9747 - loss: 0.1026 - val_accuracy: 0.9622 - val_loss: 0.1486
# Epoch 38/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9681 - loss: 0.1081 - val_accuracy: 0.9600 - val_loss: 0.1443
# Epoch 39/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9804 - loss: 0.0998 - val_accuracy: 0.9622 - val_loss: 0.1418
# Epoch 40/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9789 - loss: 0.0881 - val_accuracy: 0.9600 - val_loss: 0.1355
# Epoch 41/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9813 - loss: 0.0930 - val_accuracy: 0.9578 - val_loss: 0.1353
# Epoch 42/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9793 - loss: 0.0876 - val_accuracy: 0.9578 - val_loss: 0.1391
# Epoch 43/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9873 - loss: 0.0740 - val_accuracy: 0.9644 - val_loss: 0.1326
# Epoch 44/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9766 - loss: 0.0803 - val_accuracy: 0.9622 - val_loss: 0.1310
# Epoch 45/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9844 - loss: 0.0782 - val_accuracy: 0.9644 - val_loss: 0.1278
# Epoch 46/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9831 - loss: 0.0772 - val_accuracy: 0.9667 - val_loss: 0.1309
# Epoch 47/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9849 - loss: 0.0735 - val_accuracy: 0.9644 - val_loss: 0.1263
# Epoch 48/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9879 - loss: 0.0746 - val_accuracy: 0.9622 - val_loss: 0.1257
# Epoch 49/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9913 - loss: 0.0628 - val_accuracy: 0.9667 - val_loss: 0.1222
# Epoch 50/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9889 - loss: 0.0677 - val_accuracy: 0.9711 - val_loss: 0.1182
# Epoch 51/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9903 - loss: 0.0653 - val_accuracy: 0.9689 - val_loss: 0.1186
# Epoch 52/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9920 - loss: 0.0596 - val_accuracy: 0.9689 - val_loss: 0.1217
# Epoch 53/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0586 - val_accuracy: 0.9689 - val_loss: 0.1219
# Epoch 54/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9884 - loss: 0.0660 - val_accuracy: 0.9689 - val_loss: 0.1172
# Epoch 55/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9920 - loss: 0.0548 - val_accuracy: 0.9622 - val_loss: 0.1194
# Epoch 56/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9916 - loss: 0.0551 - val_accuracy: 0.9733 - val_loss: 0.1130
# Epoch 57/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9911 - loss: 0.0591 - val_accuracy: 0.9689 - val_loss: 0.1116
# Epoch 58/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9930 - loss: 0.0497 - val_accuracy: 0.9711 - val_loss: 0.1086
# Epoch 59/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9951 - loss: 0.0514 - val_accuracy: 0.9711 - val_loss: 0.1176
# Epoch 60/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9950 - loss: 0.0521 - val_accuracy: 0.9689 - val_loss: 0.1096
# Epoch 61/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0573 - val_accuracy: 0.9711 - val_loss: 0.1069
# Epoch 62/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9963 - loss: 0.0415 - val_accuracy: 0.9689 - val_loss: 0.1095
# Epoch 63/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9932 - loss: 0.0495 - val_accuracy: 0.9644 - val_loss: 0.1104
# Epoch 64/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9926 - loss: 0.0515 - val_accuracy: 0.9733 - val_loss: 0.1059
# Epoch 65/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0521 - val_accuracy: 0.9733 - val_loss: 0.1111
# Epoch 66/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9962 - loss: 0.0478 - val_accuracy: 0.9711 - val_loss: 0.1087
# Epoch 67/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9976 - loss: 0.0381 - val_accuracy: 0.9711 - val_loss: 0.1043
# Epoch 68/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9953 - loss: 0.0389 - val_accuracy: 0.9689 - val_loss: 0.1044
# Epoch 69/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9956 - loss: 0.0339 - val_accuracy: 0.9733 - val_loss: 0.1036
# Epoch 70/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9968 - loss: 0.0374 - val_accuracy: 0.9711 - val_loss: 0.1029
# Epoch 71/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9970 - loss: 0.0366 - val_accuracy: 0.9711 - val_loss: 0.1034
# Epoch 72/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9978 - loss: 0.0372 - val_accuracy: 0.9711 - val_loss: 0.1092
# Epoch 73/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9993 - loss: 0.0313 - val_accuracy: 0.9667 - val_loss: 0.1078
# Epoch 74/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9940 - loss: 0.0379 - val_accuracy: 0.9689 - val_loss: 0.1001
# Epoch 75/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9936 - loss: 0.0380 - val_accuracy: 0.9711 - val_loss: 0.1013
# Epoch 76/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9981 - loss: 0.0300 - val_accuracy: 0.9733 - val_loss: 0.1003
# Epoch 77/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9921 - loss: 0.0400 - val_accuracy: 0.9733 - val_loss: 0.0994
# Epoch 78/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9966 - loss: 0.0313 - val_accuracy: 0.9711 - val_loss: 0.1013
# Epoch 79/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9956 - loss: 0.0330 - val_accuracy: 0.9711 - val_loss: 0.0986
# Epoch 80/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9987 - loss: 0.0247 - val_accuracy: 0.9756 - val_loss: 0.1060
# Epoch 81/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9934 - loss: 0.0324 - val_accuracy: 0.9733 - val_loss: 0.1008
# Epoch 82/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9974 - loss: 0.0279 - val_accuracy: 0.9711 - val_loss: 0.0973
# Epoch 83/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9985 - loss: 0.0269 - val_accuracy: 0.9733 - val_loss: 0.0984
# Epoch 84/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0255 - val_accuracy: 0.9733 - val_loss: 0.0993
# Epoch 85/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9955 - loss: 0.0318 - val_accuracy: 0.9733 - val_loss: 0.0967
# Epoch 86/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9995 - loss: 0.0275 - val_accuracy: 0.9711 - val_loss: 0.0982
# Epoch 87/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9994 - loss: 0.0225 - val_accuracy: 0.9733 - val_loss: 0.0983
# Epoch 88/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9994 - loss: 0.0218 - val_accuracy: 0.9733 - val_loss: 0.0998
# Epoch 89/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9992 - loss: 0.0237 - val_accuracy: 0.9711 - val_loss: 0.1048
# Epoch 90/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.0249 - val_accuracy: 0.9733 - val_loss: 0.0993
# Epoch 91/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9969 - loss: 0.0256 - val_accuracy: 0.9756 - val_loss: 0.0963
# Epoch 92/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9981 - loss: 0.0262 - val_accuracy: 0.9733 - val_loss: 0.0945
# Epoch 93/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9994 - loss: 0.0251 - val_accuracy: 0.9733 - val_loss: 0.0987
# Epoch 94/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9978 - loss: 0.0239 - val_accuracy: 0.9756 - val_loss: 0.0975
# Epoch 95/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9998 - loss: 0.0189 - val_accuracy: 0.9733 - val_loss: 0.0990
# Epoch 96/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9992 - loss: 0.0180 - val_accuracy: 0.9711 - val_loss: 0.0986
# Epoch 97/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9999 - loss: 0.0200 - val_accuracy: 0.9711 - val_loss: 0.0990
# Epoch 98/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9999 - loss: 0.0190 - val_accuracy: 0.9778 - val_loss: 0.0977
# Epoch 99/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9999 - loss: 0.0191 - val_accuracy: 0.9733 - val_loss: 0.0953
# Epoch 100/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9995 - loss: 0.0179 - val_accuracy: 0.9733 - val_loss: 0.0963
# Epoch 101/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9996 - loss: 0.0160 - val_accuracy: 0.9689 - val_loss: 0.0962
# Epoch 102/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9986 - loss: 0.0168 - val_accuracy: 0.9733 - val_loss: 0.0997
# Epoch 103/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9999 - loss: 0.0133 - val_accuracy: 0.9689 - val_loss: 0.0971
# Epoch 104/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0160 - val_accuracy: 0.9733 - val_loss: 0.0945
# Epoch 105/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9997 - loss: 0.0171 - val_accuracy: 0.9733 - val_loss: 0.0980
# Epoch 106/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0139 - val_accuracy: 0.9733 - val_loss: 0.0941
# Epoch 107/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9997 - loss: 0.0158 - val_accuracy: 0.9733 - val_loss: 0.0988
# Epoch 108/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9999 - loss: 0.0131 - val_accuracy: 0.9733 - val_loss: 0.0941
# Epoch 109/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9991 - loss: 0.0137 - val_accuracy: 0.9711 - val_loss: 0.0990
# Epoch 110/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9997 - loss: 0.0114 - val_accuracy: 0.9733 - val_loss: 0.0989
# Epoch 111/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9998 - loss: 0.0125 - val_accuracy: 0.9733 - val_loss: 0.0983
# Epoch 112/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9999 - loss: 0.0123 - val_accuracy: 0.9733 - val_loss: 0.0975
# Epoch 113/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.0145 - val_accuracy: 0.9711 - val_loss: 0.1001
# Epoch 114/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9999 - loss: 0.0123 - val_accuracy: 0.9778 - val_loss: 0.0974
# Epoch 115/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9997 - loss: 0.0131 - val_accuracy: 0.9733 - val_loss: 0.0998
# Epoch 116/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9998 - loss: 0.0133 - val_accuracy: 0.9733 - val_loss: 0.0972
# Epoch 117/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9998 - loss: 0.0114 - val_accuracy: 0.9733 - val_loss: 0.0972
# Epoch 118/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0118 - val_accuracy: 0.9644 - val_loss: 0.1042
# Epoch 119/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9996 - loss: 0.0133 - val_accuracy: 0.9733 - val_loss: 0.0968
# Epoch 120/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 0.9733 - val_loss: 0.1022
# Epoch 121/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9984 - loss: 0.0113 - val_accuracy: 0.9733 - val_loss: 0.0998
# Epoch 122/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.0114 - val_accuracy: 0.9711 - val_loss: 0.0936
# Epoch 123/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 0.9667 - val_loss: 0.0952
# Epoch 124/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0097 - val_accuracy: 0.9667 - val_loss: 0.0985
# Epoch 125/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9997 - loss: 0.0093 - val_accuracy: 0.9733 - val_loss: 0.1019
# Epoch 126/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 0.9711 - val_loss: 0.0970
# Epoch 127/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0091 - val_accuracy: 0.9733 - val_loss: 0.0958
# Epoch 128/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0105 - val_accuracy: 0.9733 - val_loss: 0.0993
# Epoch 129/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 0.9689 - val_loss: 0.1003
# Epoch 130/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9999 - loss: 0.0110 - val_accuracy: 0.9689 - val_loss: 0.0995
# Epoch 131/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.9711 - val_loss: 0.1018
# Epoch 132/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 0.9733 - val_loss: 0.1040
# Epoch 133/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.9756 - val_loss: 0.1013
# Epoch 134/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.9689 - val_loss: 0.0999
# Epoch 135/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.9689 - val_loss: 0.1021
# Epoch 136/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 0.9733 - val_loss: 0.0998
# Epoch 137/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 0.9689 - val_loss: 0.1013
# Epoch 138/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 0.9733 - val_loss: 0.1019
# Epoch 139/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 0.9733 - val_loss: 0.1013
# Epoch 140/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.9667 - val_loss: 0.1008
# Epoch 141/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.9756 - val_loss: 0.1032
# Epoch 142/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.9711 - val_loss: 0.1044
# Epoch 143/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.9711 - val_loss: 0.0988
# Epoch 144/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9989 - loss: 0.0068 - val_accuracy: 0.9711 - val_loss: 0.1014
# Epoch 145/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.9733 - val_loss: 0.1042
# Epoch 146/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9996 - loss: 0.0058 - val_accuracy: 0.9711 - val_loss: 0.1010
# Epoch 147/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.9733 - val_loss: 0.1068
# Epoch 148/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.9667 - val_loss: 0.1011
# Epoch 149/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.9711 - val_loss: 0.1018
# Epoch 150/150
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.9689 - val_loss: 0.1077

# %%
# Make some nice plots

from matplotlib import pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
import matplotlib.pyplot as plt

y_val_pred_probs = model.predict(X_val, verbose=0)
y_val_pred = np.argmax(y_val_pred_probs, axis=1)

cm = confusion_matrix(y_val, y_val_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.arange(10))

fig, ax = plt.subplots(figsize=(8, 8))
disp.plot(ax=ax, cmap="viridis", values_format="d")
plt.show()

# %% [markdown]
# # Experimentation
#
# Using what you know so far, try to make the best possible model to predict diabetes with these data.
#
# Things to try:
#
# * Try normalizing data (all values between 0 and 1)
#     ```python
#     # Normalize data - all between 0 and 1
#     scaler = MinMaxScaler()
#     X = scaler.fit_transform(X)
#     ```
# * Adding layers
# * Adjusting the number of neurons per layer (you do need to get back to 1 with a sigmoid activation at the end)
# * Different activation functions
# * Adjusting the number of epochs
# * Adjusting learning rate
